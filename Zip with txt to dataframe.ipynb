# %% [markdown]
# # Convert txt file in a zip file into a dataframe
#
# You can use this script for creating dataframe from a txt file within a zipfile, without locally extracting the zipfile.

# %%
import pandas as pd
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen

# %%
# Replace url with the zipfile link
url = 'https://statbel.fgov.be/sites/default/files/files/opendata/bevolking%20naar%20woonplaats%2C%20nationaliteit%20burgelijke%20staat%20%2C%20leeftijd%20en%20geslacht/TF_SOC_POP_STRUCT_2019.zip'
resp = urlopen(url)
zipfile = ZipFile(BytesIO(resp.read()))

# %%
# if you don't know the name of the txt file in de zip file, run this code and copy the result
zipfile.namelist()

# %%
#replace the filename in file with the name you've copied
file = 'TF_SOC_POP_STRUCT_2019.txt'
txt = zipfile.open(file)
#replace delimiter as necessary
df = pd.read_csv(txt, delimiter = "|")

# %%
df.head()
# Out:
#    CD_REFNIS TX_DESCR_NL TX_DESCR_FR  CD_DSTR_REFNIS  \
# 0      11001  Aartselaar  Aartselaar           11000
# 1      11001  Aartselaar  Aartselaar           11000
# 2      11001  Aartselaar  Aartselaar           11000
# 3      11001  Aartselaar  Aartselaar           11000
# 4      11001  Aartselaar  Aartselaar           11000
#
#        TX_ADM_DSTR_DESCR_NL     TX_ADM_DSTR_DESCR_FR  CD_PROV_REFNIS  \
# 0  Arrondissement Antwerpen  Arrondissement d’Anvers         10000.0
# 1  Arrondissement Antwerpen  Arrondissement d’Anvers         10000.0
# 2  Arrondissement Antwerpen  Arrondissement d’Anvers         10000.0
# 3  Arrondissement Antwerpen  Arrondissement d’Anvers         10000.0
# 4  Arrondissement Antwerpen  Arrondissement d’Anvers         10000.0
#
#       TX_PROV_DESCR_NL   TX_PROV_DESCR_FR  CD_RGN_REFNIS  ...  \
# 0  Provincie Antwerpen  Province d’Anvers           2000  ...
# 1  Provincie Antwerpen  Province d’Anvers           2000  ...
# ...
